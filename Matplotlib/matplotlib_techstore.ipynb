# %% [markdown]
# # Matplotlib: TechStore
#
# **Análisis visual de ventas 2024**

# %% [markdown]
# ## Setup
#
# Importación de librerías necesarias:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Carga de Datos
#
# Ejecuta esta celda para cargar el dataset:

# %%
# Generar dataset de ventas TechStore 2024
np.random.seed(42)
meses = ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun',
         'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic']

ventas = pd.DataFrame({
    'mes': meses,
    'laptops': np.random.randint(80, 200, 12),
    'smartphones': np.random.randint(150, 400, 12),
    'tablets': np.random.randint(50, 150, 12),
    'accesorios': np.random.randint(200, 500, 12)
})

print("Dataset TechStore cargado correctamente")
print(ventas.head())
print(f"\nForma: {ventas.shape}")
# Out:
# Dataset TechStore cargado correctamente
#    mes  laptops  smartphones  tablets  accesorios
# 0  Ene      182          352       79         258
# 1  Feb      131          237       87         369
# 2  Mar      172          266       51         387
# 3  Abr       94          249      113         470
# 4  May      186          253      109         389
#
# Forma: (12, 5)

# %% [markdown]
# ## Ejercicio 1: Exploración inicial
#
# **Objetivo:** Conocer los datos antes de visualizar
#
# Antes de crear gráficos, explora el DataFrame con describe() para entender las distribuciones.

# %% [markdown]
# ### Tareas
#
# - Muestra las primeras filas del DataFrame
# - Ejecuta describe() sobre las columnas numéricas
# - Identifica qué producto tiene mayor variabilidad
# - ¿Cuál es el mes con más ventas totales?

# %%
# EJERCICIO 1: Exploración Inicial
# Dataset disponible: ventas (DataFrame con mes, laptops, smartphones, tablets, accesorios)

# 1. Mostrar primeras filas
print("Primeras filas del dataset:")
print(ventas.head())

# 2. Estadísticas descriptivas
print("\nEstadísticas descriptivas del dataset:")
print(ventas.describe())

# 3. Calcular ventas totales por mes
print("\nVentas totales por mes:")
ventas['total'] = ventas[['laptops', 'smartphones', 'tablets', 'accesorios']].sum(axis=1)
print(ventas[['mes', 'total']])
# Out:
# Primeras filas del dataset:
#    mes  laptops  smartphones  tablets  accesorios
# 0  Ene      182          352       79         258
# 1  Feb      131          237       87         369
# 2  Mar      172          266       51         387
# 3  Abr       94          249      113         470
# 4  May      186          253      109         389
#
# Estadísticas descriptivas del dataset:
#           laptops  smartphones     tablets  accesorios
# count   12.000000    12.000000   12.000000   12.000000
# mean   151.666667   267.666667   94.166667  339.833333
# std     30.612931    62.881322   25.297622   80.267545
# min     94.000000   151.000000   51.000000  220.000000
# 25%    137.750000   237.000000   77.000000  257.000000
# 50%    158.000000   259.500000   92.500000  351.500000
# 75%    174.500000   299.500000  110.000000  387.500000
# max    186.000000   385.000000  138.000000  470.000000
#
# Ventas totales por mes:
#     mes  total
# 0   Ene    871
# 1   Feb    824
# 2   Mar    876
# ...

# %% [markdown]
# <details>
# <summary><strong>Solucion (click para ver)</strong></summary>
#
# ```python
# # EJERCICIO 1: Exploración Inicial
#
# # 1. Mostrar primeras filas
# print("=== PRIMERAS FILAS ===")
# print(ventas.head())
#
# # 2. Estadísticas descriptivas
# print("\n=== ESTADÍSTICAS DESCRIPTIVAS ===")
# print(ventas.describe())
#
# # 3. Calcular ventas totales por mes
# cols_productos = ['laptops', 'smartphones', 'tablets', 'accesorios']
# ventas['total'] = ventas[cols_productos].sum(axis=1)
# print("\n=== VENTAS TOTALES POR MES ===")
# print(ventas[['mes', 'total']])
#
# # Mes con más ventas
# idx_max = ventas['total'].idxmax()
# print(f"\nMes con más ventas: {ventas.loc[idx_max, 'mes']} ({ventas.loc[idx_max, 'total']} unidades)")
#
# ```
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## Ejercicio 1: Gráfico de línea - Evolución mensual
#
# **Objetivo:** Crear un gráfico de línea con múltiples series
#
# Queremos ver la evolución de ventas de los 4 productos a lo largo del año. Cada producto debe tener su propia línea con color, marcador y etiqueta.

# %% [markdown]
# ### Tareas
#
# - Crear figura y axes con plt.subplots()
# - Dibujar una línea por producto con ax.plot()
# - Cada línea con color diferente y marcador
# - Añadir título, etiquetas de ejes y leyenda
# - Añadir grid para facilitar lectura

# %%
# EJERCICIO 2: Gráfico de Línea - Evolución de Ventas
# Dataset: ventas (DataFrame)

fig, ax = plt.subplots(figsize=(12, 6))

# Dibujar línea para cada producto
ax.plot(ventas['mes'], ventas['laptops'], marker='o', lw=2,
        color='#2563EB', label='Laptops')

# TODO: Añadir smartphones (color rojo #DC2626, marker='s')
ax.plot(ventas['mes'], ventas['smartphones'], marker='s', lw=2,
        color='#DC2626', label='Smartphones')

# TODO: Añadir tablets (color verde #059669, marker='^')
ax.plot(ventas['mes'], ventas['tablets'], marker='^', lw=2,
        color='#059669', label='Tablets')

# TODO: Añadir accesorios (color naranja #D97706, marker='D')
ax.plot(ventas['mes'], ventas['accesorios'], marker='D', lw=2,
        color='#D97706', label='Accesorios')

# Personalización
ax.set_title('Ventas Mensuales por Producto - TechStore 2024',
             fontsize=16, fontweight='bold')
ax.set_xlabel('Mes', fontsize=12)
ax.set_ylabel('Unidades vendidas', fontsize=12)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# <details>
# <summary><strong>Solucion (click para ver)</strong></summary>
#
# ```python
# # EJERCICIO 2: Gráfico de Línea - Evolución de Ventas
#
# fig, ax = plt.subplots(figsize=(12, 6))
#
# # Dibujar línea para cada producto
# ax.plot(ventas['mes'], ventas['laptops'], marker='o', lw=2,
#         color='#2563EB', label='Laptops')
# ax.plot(ventas['mes'], ventas['smartphones'], marker='s', lw=2,
#         color='#DC2626', label='Smartphones')
# ax.plot(ventas['mes'], ventas['tablets'], marker='^', lw=2,
#         color='#059669', label='Tablets')
# ax.plot(ventas['mes'], ventas['accesorios'], marker='D', lw=2,
#         color='#D97706', label='Accesorios')
#
# # Personalización
# ax.set_title('Ventas Mensuales por Producto - TechStore 2024',
#              fontsize=16, fontweight='bold')
# ax.set_xlabel('Mes', fontsize=12)
# ax.set_ylabel('Unidades vendidas', fontsize=12)
# ax.legend(fontsize=11)
# ax.grid(True, alpha=0.3)
#
# plt.tight_layout()
# plt.show()
#
# ```
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## Ejercicio 2: Scatter plot - Relación entre variables
#
# **Objetivo:** Visualizar correlación con color como tercera dimensión
#
# Queremos ver si hay relación entre las ventas de laptops y smartphones. Además, usaremos el color para representar el mes (0=Enero, 11=Diciembre).

# %% [markdown]
# ### Tareas
#
# - Crear scatter plot con laptops en X y smartphones en Y
# - Colorear puntos según el mes (usar np.arange(12))
# - Añadir barra de color con plt.colorbar()
# - Personalizar con título y etiquetas

# %%
ventas
# Out:
#     mes  laptops  smartphones  tablets  accesorios  total
# 0   Ene      182          352       79         258    871
# 1   Feb      131          237       87         369    824
# 2   Mar      172          266       51         387    876
# 3   Abr       94          249      113         470    926
# 4   May      186          253      109         389    937
# 5   Jun      151          301       70         374    896
# 6   Jul      140          280       82         250    752
# 7   Ago      100          299      125         254    778
# 8   Sep      182          202      107         443    934
# 9   Oct      162          151       71         330    714
# 10  Nov      166          237      138         334    875
# 11  Dic      154          385       98         220    857

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10, 6))

lineplot = sns.lineplot(
    data = ventas,
    x = 'laptops',
    y = 'mes',
    palette = 'Set3',
    markers = True
)
plt.show()

# %%
# EJERCICIO 3: Scatter Plot - Relación Laptops vs Smartphones

fig, ax = plt.subplots(figsize=(10, 6))

# TODO: Crear scatter plot
# - X: ventas['laptops']
# - Y: ventas['smartphones']
# - Color: np.arange(12) para representar mes
# - Usar cmap='viridis', s=100, edgecolors='black'
scatter = ax.scatter(ventas['laptops'], ventas['smartphones'],
                     c=np.arange(12), cmap='Set3', s=100, edgecolors='black')

# TODO: Añadir colorbar
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Mes (0=Ene, 11=Dic)', rotation=270, labelpad=15)

# Personalización
ax.set_title('Relación Laptops vs Smartphones',
             fontsize=16, fontweight='bold')
ax.set_xlabel('Ventas Laptops', fontsize=12)
ax.set_ylabel('Ventas Smartphones', fontsize=12)
ax.legend('Mes')


plt.tight_layout()
plt.show()

# %% [markdown]
# <details>
# <summary><strong>Solucion (click para ver)</strong></summary>
#
# ```python
# # EJERCICIO 3: Scatter Plot - Relación Laptops vs Smartphones
#
# fig, ax = plt.subplots(figsize=(10, 6))
#
# # Scatter plot con color por mes
# scatter = ax.scatter(
#     ventas['laptops'],
#     ventas['smartphones'],
#     c=np.arange(12),
#     cmap='viridis',
#     s=100,
#     edgecolors='black',
#     linewidth=0.5,
#     alpha=0.8
# )
#
# # Colorbar
# cbar = plt.colorbar(scatter, ax=ax)
# cbar.set_label('Mes (0=Ene, 11=Dic)', fontsize=11)
#
# # Personalización
# ax.set_title('Relación Laptops vs Smartphones',
#              fontsize=16, fontweight='bold')
# ax.set_xlabel('Ventas Laptops', fontsize=12)
# ax.set_ylabel('Ventas Smartphones', fontsize=12)
# ax.grid(True, alpha=0.3)
#
# plt.tight_layout()
# plt.show()
#
# ```
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## Ejercicio 3: Subplots 2x2 - Dashboard
#
# **Objetivo:** Crear una cuadrícula de gráficos para comparar productos
#
# Crea un dashboard con 4 gráficos de barras, uno por producto, mostrando las ventas mensuales de cada uno.

# %% [markdown]
# ### Tareas
#
# - Crear figura con subplots(2, 2)
# - Un gráfico de barras por producto
# - Acceder a cada axes con axes[fila, columna]
# - Añadir título general con fig.suptitle()

# %%
# EJERCICIO 4: Subplots 2x2 - Dashboard por Producto

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

productos = ['laptops', 'smartphones', 'tablets', 'accesorios']
colores = ['#2563EB', '#DC2626', '#059669', '#D97706']

# TODO: Crear un gráfico de barras para cada producto
# Usar axes[fila, col].bar(ventas['mes'], ventas[producto], color=color)
# Añadir título a cada subplot
for i, producto in enumerate(productos):
    row, col = divmod(i, 2)
    axes[row, col].bar(ventas['mes'], ventas[producto], color=colores[i])
    axes[row, col].set_title(f'Ventas de {producto.capitalize()}',
                             fontsize=14, fontweight='bold')
    axes[row, col].set_xlabel('Mes', fontsize=10)
    axes[row, col].set_ylabel('Unidades vendidas', fontsize=10)
    axes[row, col].grid(True, alpha=0.3)

# Título general
fig.suptitle('Ventas por Producto - TechStore 2024',
             fontsize=18, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
sns.barplot(
    data = productos,
    x = 'meses',
    y = 'ventas',
    hue = 'productos',
    palette = 'Set2'

)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sns.barplot(
#       2     data = productos,
#       3     x = 'meses',
#       4     y = 'ventas',
#       5     hue = 'productos',
#       6     palette = 'Set2'
#       7
#       8 )
#
# File c:\Users\frasq\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
# ...

# %% [markdown]
# <details>
# <summary><strong>Solucion (click para ver)</strong></summary>
#
# ```python
# # EJERCICIO 4: Subplots 2x2 - Dashboard por Producto
#
# fig, axes = plt.subplots(2, 2, figsize=(14, 10))
#
# productos = ['laptops', 'smartphones', 'tablets', 'accesorios']
# colores = ['#2563EB', '#DC2626', '#059669', '#D97706']
#
# for idx, (producto, color) in enumerate(zip(productos, colores)):
#     fila = idx // 2
#     col = idx % 2
#
#     axes[fila, col].bar(ventas['mes'], ventas[producto],
#                         color=color, alpha=0.8,
#                         edgecolor='black', linewidth=0.5)
#     axes[fila, col].set_title(producto.capitalize(),
#                               fontsize=14, fontweight='bold')
#     axes[fila, col].set_ylabel('Unidades')
#     axes[fila, col].tick_params(axis='x', rotation=45)
#     axes[fila, col].grid(True, alpha=0.3, axis='y')
#
# # Título general
# fig.suptitle('Ventas por Producto - TechStore 2024',
#              fontsize=18, fontweight='bold')
#
# plt.tight_layout()
# plt.show()
#
# ```
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## Ejercicio 4: Personalización avanzada
#
# **Objetivo:** Añadir líneas de referencia y anotaciones
#
# Mejora el gráfico de smartphones añadiendo una línea horizontal con la media y una anotación señalando el mes con más ventas.

# %% [markdown]
# ### Tareas
#
# - Crear gráfico de barras de smartphones
# - Añadir línea horizontal con la media (axhline)
# - Encontrar el mes con máximas ventas
# - Añadir anotación con flecha señalando el máximo

# %%
# EJERCICIO 5: Personalización con Media y Anotación

fig, ax = plt.subplots(figsize=(12, 6))

# Gráfico de barras
ax.bar(ventas['mes'], ventas['smartphones'],
       color='#DC2626', alpha=0.8,
       edgecolor='black', linewidth=0.5)

# TODO: Calcular y dibujar línea de media
media_smartphones = ventas['smartphones'].mean()
ax.axhline(media_smartphones, color='blue', linestyle='--',
           label=f'Media: {media_smartphones:.1f}')

# TODO: Encontrar mes con máximas ventas
max_mes = ventas.loc[ventas['smartphones'].idxmax(), 'mes']
max_valor = ventas['smartphones'].max()
ax.annotate(f'Máximo: {max_valor} en {max_mes}',
            xy=(max_mes, max_valor), xytext=(max_mes, max_valor + 20),
            arrowprops=dict(facecolor='black', shrink=0.05),
            fontsize=10, fontweight='bold', ha='center')

# TODO: Añadir anotación con flecha
min_mes = ventas.loc[ventas['smartphones'].idxmin(), 'mes']
min_valor = ventas['smartphones'].min()
ax.annotate(f'Mínimo: {min_valor} en {min_mes}',
            xy=(min_mes, min_valor), xytext=(min_mes, min_valor - 25),
            arrowprops=dict(facecolor='black', shrink=0.05),
            fontsize=10, fontweight='bold', ha='center')


# Personalización
ax.set_title('Ventas de Smartphones 2024', fontsize=16, fontweight='bold')
ax.set_xlabel('Mes', fontsize=12)
ax.set_ylabel('Unidades', fontsize=12)
ax.legend(fontsize=11)

plt.tight_layout()
plt.show()

# %% [markdown]
# <details>
# <summary><strong>Solucion (click para ver)</strong></summary>
#
# ```python
# # EJERCICIO 5: Personalización con Media y Anotación
#
# fig, ax = plt.subplots(figsize=(12, 6))
#
# # Gráfico de barras
# ax.bar(ventas['mes'], ventas['smartphones'],
#        color='#DC2626', alpha=0.8,
#        edgecolor='black', linewidth=0.5)
#
# # Línea de media
# media = ventas['smartphones'].mean()
# ax.axhline(y=media, color='black', linestyle='--', alpha=0.7,
#            label=f'Media: {media:.0f}')
#
# # Encontrar mes con máximas ventas
# idx_max = ventas['smartphones'].idxmax()
# mes_max = ventas.loc[idx_max, 'mes']
# val_max = ventas.loc[idx_max, 'smartphones']
#
# # Anotación con flecha
# ax.annotate(f'Máximo: {val_max}',
#             xy=(idx_max, val_max),
#             xytext=(idx_max + 1.5, val_max + 20),
#             arrowprops=dict(arrowstyle='->', color='black'),
#             fontsize=12, fontweight='bold')
#
# # Personalización
# ax.set_title('Ventas de Smartphones 2024', fontsize=16, fontweight='bold')
# ax.set_xlabel('Mes', fontsize=12)
# ax.set_ylabel('Unidades', fontsize=12)
# ax.legend(fontsize=11)
# ax.grid(True, alpha=0.3, axis='y')
#
# plt.tight_layout()
# plt.show()
#
# ```
#
# </details>
